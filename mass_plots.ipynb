# %%
import atmosphere as atmo
import aerodynamics as aero
import path
import rocket_parser as rp
import matplotlib.pyplot as plt

# %%
parser = rp.rocket_parser(path.rocket_lib + "electron.json")

# %%
full_mass = parser.get_full_mass()
delta_mass = parser.get_delta_mass()
stage_mass = parser.get_stage_mass()
propellant_mass = parser.get_propellant_mass()
structural_mass = parser.get_structural_mass()
block_number = parser.get_block_number()
time_points = parser.get_work_time()

# %%
plt.plot(parser.vector_time(), parser.vector_mass())
plt.title('Расчет параметра по времени полета', fontsize=16)
plt.xlabel('Время полета, с', fontsize=14)
plt.ylabel('Масса, кг', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(parser.vector_time(), parser.vector_static())
plt.title('Расчет параметра по времени полета', fontsize=16)
plt.xlabel('Время полета, с', fontsize=14)
plt.ylabel('Статический момент Sx, кг*м2', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(parser.vector_time(), parser.vector_inertia())
plt.title('Расчет параметра по времени полета', fontsize=16)
plt.xlabel('Время полета, с', fontsize=14)
plt.ylabel('Момент инерции Iz, кг*м3', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.plot(parser.vector_time()[:-1], parser.vector_center()[:-1])
plt.title('Расчет параметра по времени полета', fontsize=16)
plt.xlabel('Время полета, с', fontsize=14)
plt.ylabel('Центр масс, м', fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.show()
print(parser.vector_center())
# Out:
# [78.562391611611, 78.54800503183664, 78.5336164441254, 78.51922584571572, 78.50483323384103, 78.49043860572957, 78.47604195860455, 78.46164328968409, 78.44724259618118, 78.43283987530371, 78.41843512425439, 78.4040283402308, 78.38961952042537, 78.37520866202537, 78.36079576221282, 78.34638081816462, 78.33196382705246, 78.31754478604272, 78.30312369229665, 78.28870054297022, 78.27427533521413, 78.25984806617383, 78.24541873298946, 78.2309873327959, 78.21655386272275, 78.2021183198942, 78.18768070142919, 78.1732410044413, 78.15879922603874, 78.14435536332438, 78.12990941339567, 78.1154613733447, 78.10101124025817, 78.08655901121733, 78.07210468329798, 78.05764825357055, 78.04318971909997, 78.0287290769457, 78.01426632416171, 77.99980145779651, 77.98533447489311, 77.97086537248894, 77.95639414761598, 77.9419207973006, 77.92744531856363, 77.91296770842035, 77.89848796388044, 77.88400608194799, 77.86952205962147, 77.85503589389376, 77.84054758175203, 77.82605712017788, 77.81156450614722, 
# ...
